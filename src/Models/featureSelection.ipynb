# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
base = pd.read_csv('../DataExplore/eegPatternBandDHT.csv')
base = base.drop_duplicates(keep='first')

# %%
featureList = "kurtosis,mean,meanAmplitude,meanFrequency,median,medianFrequency,skewness,totalPower,variance,zzclassification,meandelta,meanAmplitudedelta,powerdelta,meanAdelta,meanFidelta,meanalpha,meanAmplitudealpha,poweralpha,meanAalpha,meanFialpha,meantheta,meanAmplitudetheta,powertheta,meanAtheta,meanFitheta,meanbeta,meanAmplitudebeta,powerbeta,meanAbeta,meanFibeta,meangamma,meanAmplitudegamma,powergamma,meanAgamma,meanFigamma".split(",")

exclusionList = [
            "kurtosis",
            "mean",
            "meanAmplitude",
            "meanFrequency",
            "median",
            "medianFrequency",
            "skewness",
            "totalPower",
            "variance",
            "meanAmplitudedelta",
            "powerdelta",
            "meanAdelta",
            "meanFidelta",
            "meanAmplitudealpha",
            "poweralpha",
            "meanAalpha",
            "meanFialpha",
            "meanAmplitudetheta",
            "powertheta",
            "meanAtheta",
            "meanFitheta",
            "meanAmplitudebeta",
            "powerbeta",
            "meanAbeta",
            "meanFibeta",
            "powergamma"
        ]

removed = [i for i in featureList if i not in exclusionList]
print(removed)
# Out:
# ['zzclassification', 'meandelta', 'meanalpha', 'meantheta', 'meanbeta', 'meangamma', 'meanAmplitudegamma', 'meanAgamma', 'meanFigamma']

# %%
df_hvs = base[base['zzclassification'] == 'HVS']
df_ta = base[base['zzclassification'] == 'TA']

colunas_para_plotar = base.columns.difference(['zzclassification'])

# %%
for coluna in colunas_para_plotar:
    print(coluna)
    plt.figure(figsize=(8, 6))  # Tamanho da figura
    plt.plot(df_hvs.index, df_hvs[coluna], label='HVS', color='blue', marker='o')
    plt.plot(df_ta.index, df_ta[coluna], label='TA', color='red', marker='x')
    plt.xlabel('Índice')
    plt.ylabel(coluna)
    plt.title(f'Gráfico de {coluna}')
    plt.legend()
    plt.show()
# Out:
# kurtosis
# mean
# meanAalpha
# meanAbeta
# meanAdelta
# meanAgamma
# meanAmplitude
# meanAmplitudealpha
# meanAmplitudebeta
# meanAmplitudedelta
# meanAmplitudegamma
# meanAmplitudetheta
# meanAtheta
# meanFialpha
# meanFibeta
# meanFidelta
# meanFigamma
# meanFitheta
# meanFrequency
# meanalpha
# meanbeta
# meandelta
# meangamma
# meantheta
# median
# medianFrequency
# poweralpha
# powerbeta
# powerdelta
# powergamma
# powertheta
# skewness
# totalPower
# variance
